# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import cleaning_functions as clean
# %matplotlib inline

pd.set_option('display.max_rows', 200)

# %%
# reading in the raw data
health_df = pd.read_csv('data/analytic_data2019.csv', skiprows=1)

# %%
# dropping columns without any values
health_df.dropna(axis=1, how='all', inplace=True)

# %%
# dropping columns with the confidence intervals
# as well as the underlying numerators and denominators of the calulated metrics
health_df = clean.drop_ci_num_denom(health_df)

# %%
# generating a dictionary with the raw column names and more interpretable names
data_path = 'data/analytic_data2019.csv'
columns_dict = clean.create_column_dict(data_path)

# renaming the columns to be more interpretable
health_df.rename(columns=columns_dict, inplace=True)

# %%
# dropping rows that are not "county ranked" as they have less data and no premature death info
# also dropping national and state-level data to leave only county-level data
county_health_df = health_df[health_df.county_ranked == 1].copy()
county_health_df.reset_index(inplace=True, drop=True)

# %%
# creating a dataframe listing each column along with its count of NaN values
# to explore which metrics have enough coverage to be usable
na_count_df = clean.column_na_count_df(county_health_df)
na_count_df
# Out:
#                                                 column  na_count
# 0                                            statecode         0
# 1                                           countycode         0
# 2                                             fipscode         0
# 3                                                state         0
# 4                                               county         0
# 5                                                 year         0
# 6                                        county_ranked         0
# 7                            premature_death_raw_value         0
# 8                                premature_death_black      1728
# 9                             premature_death_hispanic      2243
# 10                               premature_death_white      1500
# 11                       poor_or_fair_health_raw_value         0
# 12                 poor_physical_health_days_raw_value         0
# 13                   poor_mental_health_days_raw_value         0
# 14                           low_birthweight_raw_value        53
# 15                               low_birthweight_black      1692
# 16                            low_birthweight_hispanic      1677
# 17                               low_birthweight_white      1265
# 18                             adult_smoking_raw_value         0
# 19                             adult_obesity_raw_value         0
# 20                    food_environment_index_raw_value        19
# 21                       physical_inactivity_raw_value         0
# 22          access_to_exercise_opportunities_raw_value         5
# 23                        excessive_drinking_raw_value         0
# 24           alcohol_impaired_driving_deaths_raw_value        22
# 25           sexually_transmitted_infections_raw_value       105
# 26                               teen_births_raw_value        86
# 27                                   teen_births_black      1693
# 28                                teen_births_hispanic      1506
# 29                                   teen_births_white      1155
# 30                                 uninsured_raw_value         0
# 31                   primary_care_physicians_raw_value       134
# 32      ratio_of_population_to_primary_care_physicians       134
# 33                                  dentists_raw_value        85
# 34                     ratio_of_population_to_dentists        85
# 35                   mental_health_providers_raw_value       230
# 36      ratio_of_population_to_mental_health_providers       230
# 37                preventable_hospital_stays_raw_value        17
# 38                    preventable_hospital_stays_black      1600
# 39                 preventable_hospital_stays_hispanic      2064
# 40                    preventable_hospital_stays_white      1306
# 41                     mammography_screening_raw_value        11
# 42                         mammography_screening_black      1536
# 43                      mammography_screening_hispanic      1700
# 44                         mammography_screening_white      1115
# 45                          flu_vaccinations_raw_value        10
# 46                              flu_vaccinations_black      1231
# 47                           flu_vaccinations_hispanic      1250
# 48                              flu_vaccinations_white       789
# 49                    high_school_graduation_raw_value        77
# 50                              some_college_raw_value         0
# 51                              unemployment_raw_value         0
# 52                       children_in_poverty_raw_value         0
# 53                           children_in_poverty_black      1076
# 54                        children_in_poverty_hispanic       429
# 55                           children_in_poverty_white       268
# 56                         income_inequality_raw_value         0
# 57      children_in_single_parent_households_raw_value         0
# 58                       social_associations_raw_value         0
# 59                             violent_crime_raw_value       173
# 60                             injury_deaths_raw_value        47
# 61          air_pollution_particulate_matter_raw_value        29
# 62                 drinking_water_violations_raw_value        42
# 63                   severe_housing_problems_raw_value         0
# 64    percentage_of_households_with_high_housing_costs         0
# 65          percentage_of_households_with_overcrowding         0
# 66   percentage_of_households_with_lack_of_kitchen_...         0
# 67                     driving_alone_to_work_raw_value         0
# 68                         driving_alone_to_work_black      1903
# 69                      driving_alone_to_work_hispanic      1798
# 70                         driving_alone_to_work_white      1421
# 71                long_commute_driving_alone_raw_value         0
# 72                           life_expectancy_raw_value        20
# 73                               life_expectancy_black      1742
# 74                            life_expectancy_hispanic      1834
# 75                               life_expectancy_white      1355
# 76          premature_age_adjusted_mortality_raw_value         0
# 77              premature_age_adjusted_mortality_black      1728
# 78           premature_age_adjusted_mortality_hispanic      2243
# 79              premature_age_adjusted_mortality_white      1500
# 80                           child_mortality_raw_value      1161
# 81                               child_mortality_black      2573
# 82                            child_mortality_hispanic      2707
# 83                               child_mortality_white      2460
# 84                          infant_mortality_raw_value      1821
# 85                              infant_mortality_black      2731
# 86                           infant_mortality_hispanic      2849
# 87                              infant_mortality_white      2675
# 88                frequent_physical_distress_raw_value         0
# 89                  frequent_mental_distress_raw_value         0
# 90                       diabetes_prevalence_raw_value         0
# 91                            hiv_prevalence_raw_value       660
# 92                           food_insecurity_raw_value         0
# 93           limited_access_to_healthy_foods_raw_value        19
# 94                      drug_overdose_deaths_raw_value      1361
# 95                motor_vehicle_crash_deaths_raw_value       382
# 96                        insufficient_sleep_raw_value         0
# 97                          uninsured_adults_raw_value         0
# 98                        uninsured_children_raw_value         0
# 99              other_primary_care_providers_raw_value        26
# 100  ratio_of_population_to_primary_care_providers_...        26
# 101                       disconnected_youth_raw_value      1669
# 102                  median_household_income_raw_value         0
# 103                      median_household_income_black      1147
# 104                   median_household_income_hispanic       649
# 105                      median_household_income_white       364
# 106  children_eligible_for_free_or_reduced_price_lu...       118
# 107      residential_segregation_black_white_raw_value      1022
# 108  residential_segregation_non_white_white_raw_value       286
# 109                                homicides_raw_value      1809
# 110                       firearm_fatalities_raw_value       872
# 111                            homeownership_raw_value         0
# 112               severe_housing_cost_burden_raw_value         0
# 113                               population_raw_value         0
# 114                pct_below_18_years_of_age_raw_value         0
# 115                         pct_65_and_older_raw_value         0
# 116        pct_non_hispanic_african_american_raw_value         0
# 117   pct_american_indian_and_alaskan_native_raw_value         0
# 118                                pct_asian_raw_value         0
# 119  pct_native_hawaiian_other_pacific_islander_raw...         0
# 120                             pct_hispanic_raw_value         0
# 121                   pct_non_hispanic_white_raw_value         0
# 122            pct_not_proficient_in_english_raw_value         0
# 123                              pct_females_raw_value         0
# 124                                pct_rural_raw_value         6
# 125                     communicable_disease_raw_value      3009
# 126   self_inflicted_injury_hospitalizations_raw_value      3012
# 127                         cancer_incidence_raw_value      3009
# 128  coronary_heart_disease_hospitalizations_raw_value      3011
# 129  cerebrovascular_disease_hospitalizations_raw_v...      3011
# 130                 smoking_during_pregnancy_raw_value      3009
# 131                             drug_arrests_raw_value      3010
# 132                   opioid_hospital_visits_raw_value      3010
# 133         alcohol_related_hospitalizations_raw_value      3019
# 134       motor_vehicle_crash_occupancy_rate_raw_value      3009
# 135  on_road_motor_vehicle_crash_related_er_visits_...      3009
# 136  off_road_motor_vehicle_crash_related_er_visits...      3010
# 137                  childhood_immunizations_raw_value      3009
# 138                      reading_proficiency_raw_value      3009
# 139                           w_2_enrollment_raw_value      3009
# 140                                  poverty_raw_value      3009
# 141                older_adults_living_alone_raw_value      3009
# 142                              hate_crimes_raw_value      3069
# 143                              child_abuse_raw_value      3009
# 144                  injury_hospitalizations_raw_value      3009
# 145                   fall_fatalities_65plus_raw_value      3017
# 146                     year_structure_built_raw_value      3009
# 147                     male_population_0_17_raw_value      3009
# 148                    male_population_18_44_raw_value      3009
# 149                    male_population_45_64_raw_value      3009
# 150                   male_population_65plus_raw_value      3009
# 151                    total_male_population_raw_value      3009
# 152                   female_population_0_17_raw_value      3009
# 153                  female_population_18_44_raw_value      3009
# 154                  female_population_45_64_raw_value      3009
# 155                 female_population_65plus_raw_value      3009
# 156                  total_female_population_raw_value      3009
# 157                        population_growth_raw_value      3009

# %%
# observing racial cross-tabs have mostly significant missing values
na_count_df.loc[na_count_df.column.apply(lambda x: x.find('hispanic')) > -1]
# Out:
#                                           column  na_count
# 9                       premature_death_hispanic      2243
# 16                      low_birthweight_hispanic      1677
# 28                          teen_births_hispanic      1506
# 39           preventable_hospital_stays_hispanic      2064
# 43                mammography_screening_hispanic      1700
# 47                     flu_vaccinations_hispanic      1250
# 54                  children_in_poverty_hispanic       429
# 69                driving_alone_to_work_hispanic      1798
# 74                      life_expectancy_hispanic      1834
# 78     premature_age_adjusted_mortality_hispanic      2243
# 82                      child_mortality_hispanic      2707
# 86                     infant_mortality_hispanic      2849
# 104             median_household_income_hispanic       649
# 116  pct_non_hispanic_african_american_raw_value         0
# 120                       pct_hispanic_raw_value         0
# 121             pct_non_hispanic_white_raw_value         0

# %%
# Decided to drop race-based cross-tab with missing values.
# All but the overall population pct had many missing values based on race.
county_health_df = clean.drop_race_cross_tabs(county_health_df)

# %%
# the last 33 columns all have 3009+ missing values.
na_count_df[na_count_df.na_count >= 3009]
# Out:
#                                                 column  na_count
# 125                     communicable_disease_raw_value      3009
# 126   self_inflicted_injury_hospitalizations_raw_value      3012
# 127                         cancer_incidence_raw_value      3009
# 128  coronary_heart_disease_hospitalizations_raw_value      3011
# 129  cerebrovascular_disease_hospitalizations_raw_v...      3011
# 130                 smoking_during_pregnancy_raw_value      3009
# 131                             drug_arrests_raw_value      3010
# 132                   opioid_hospital_visits_raw_value      3010
# 133         alcohol_related_hospitalizations_raw_value      3019
# 134       motor_vehicle_crash_occupancy_rate_raw_value      3009
# 135  on_road_motor_vehicle_crash_related_er_visits_...      3009
# 136  off_road_motor_vehicle_crash_related_er_visits...      3010
# 137                  childhood_immunizations_raw_value      3009
# 138                      reading_proficiency_raw_value      3009
# 139                           w_2_enrollment_raw_value      3009
# 140                                  poverty_raw_value      3009
# 141                older_adults_living_alone_raw_value      3009
# 142                              hate_crimes_raw_value      3069
# 143                              child_abuse_raw_value      3009
# 144                  injury_hospitalizations_raw_value      3009
# 145                   fall_fatalities_65plus_raw_value      3017
# 146                     year_structure_built_raw_value      3009
# 147                     male_population_0_17_raw_value      3009
# 148                    male_population_18_44_raw_value      3009
# 149                    male_population_45_64_raw_value      3009
# 150                   male_population_65plus_raw_value      3009
# 151                    total_male_population_raw_value      3009
# 152                   female_population_0_17_raw_value      3009
# 153                  female_population_18_44_raw_value      3009
# 154                  female_population_45_64_raw_value      3009
# 155                 female_population_65plus_raw_value      3009
# 156                  total_female_population_raw_value      3009
# 157                        population_growth_raw_value      3009

# %%
# Decided to drop when NaN count is greater than or equal to 3060 
# as there is clear pattern that this data is only present for a small subset of counties
na_threshold = county_health_df.shape[0] - 3008
county_health_df.dropna(axis=1, thresh=na_threshold, inplace=True)

# %%
# All places missing pct_rural are in alaska and south dakota, presumably they are entirely rural
county_health_df[county_health_df.pct_rural_raw_value.isna()]
# Out:
#       statecode  countycode  fipscode state  \
# 74            2         105      2105    AK
# 79            2         158      2158    AK
# 85            2         195      2195    AK
# 86            2         198      2198    AK
# 90            2         275      2275    AK
# 2364         46         102     46102    SD
#
#                                  county  year  county_ranked  \
# 74            Hoonah-Angoon Census Area  2019            1.0
# 79                 Kusilvak Census Area  2019            1.0
# 85               Petersburg Census Area  2019            1.0
# 86    Prince of Wales-Hyder Census Area  2019            1.0
# 90                        Wrangell City  2019            1.0
# 2364               Oglala Lakota County  2019            1.0
#
#       premature_death_raw_value  poor_or_fair_health_raw_value  \
# 74                  7824.927522                       0.172805
# 79                 20346.044759                       0.379484
# 85                  9433.088816                       0.131575
# 86                 11628.029401                       0.192957
# 90                  6286.724229                       0.156253
# 2364               29782.937533                       0.334061
#
#       poor_physical_health_days_raw_value  ...  pct_65_and_older_raw_value  \
# 74                               4.105771  ...                    0.222378
# 79                               7.230990  ...                    0.058766
# 85                               3.375766  ...                    0.184395
# 86                               4.449669  ...                    0.158311
# 90                               3.794439  ...                    0.223721
# 2364                             6.357596  ...                    0.070155
#
#       pct_non_hispanic_african_american_raw_value  \
# 74                                       0.009324
# 79                                       0.003414
# 85                                       0.016763
# 86                                       0.004967
# 90                                       0.004760
# 2364                                     0.003344
#
#       pct_american_indian_and_alaskan_native_raw_value  pct_asian_raw_value  \
# 74                                            0.389744             0.014918
# 79                                            0.926969             0.003780
# 85                                            0.109418             0.029564
# 86                                            0.428527             0.009157
# 90                                            0.163031             0.024990
# 2364                                          0.925944             0.001324
#
#       pct_native_hawaiian_other_pacific_islander_raw_value  \
# 74                                             0.000466
# 79                                             0.000122
# 85                                             0.012801
# 86                                             0.004035
# 90                                             0.001190
# 2364                                           0.000557
#
#       pct_hispanic_raw_value  pct_non_hispanic_white_raw_value  \
# 74                  0.055478                          0.463403
# 79                  0.018410                          0.036333
# 85                  0.060043                          0.711064
# 86                  0.038647                          0.456309
# 90                  0.024990                          0.687029
# 2364                0.036018                          0.044657
#
#       pct_not_proficient_in_english_raw_value  pct_females_raw_value  \
# 74                                   0.000000               0.468065
# 79                                   0.012085               0.477932
# 85                                   0.004580               0.469064
# 86                                   0.000000               0.452119
# 90                                   0.011431               0.473225
# 2364                                 0.012516               0.509196
#
#       pct_rural_raw_value
# 74                    NaN
# 79                    NaN
# 85                    NaN
# 86                    NaN
# 90                    NaN
# 2364                  NaN
#
# [6 rows x 84 columns]

# %%
# filling missing pct_rural values with 1 as those counties are presumably rural
county_health_df.pct_rural_raw_value.fillna(value=1, inplace=True)

# %%
# exploring NaN's again
county_na_count_df = clean.column_na_count_df(county_health_df)
county_na_count_df
# Out:
#                                                column  na_count
# 0                                           statecode         0
# 1                                          countycode         0
# 2                                            fipscode         0
# 3                                               state         0
# 4                                              county         0
# 5                                                year         0
# 6                                       county_ranked         0
# 7                           premature_death_raw_value         0
# 8                       poor_or_fair_health_raw_value         0
# 9                 poor_physical_health_days_raw_value         0
# 10                  poor_mental_health_days_raw_value         0
# 11                          low_birthweight_raw_value        53
# 12                            adult_smoking_raw_value         0
# 13                            adult_obesity_raw_value         0
# 14                   food_environment_index_raw_value        19
# 15                      physical_inactivity_raw_value         0
# 16         access_to_exercise_opportunities_raw_value         5
# 17                       excessive_drinking_raw_value         0
# 18          alcohol_impaired_driving_deaths_raw_value        22
# 19          sexually_transmitted_infections_raw_value       105
# 20                              teen_births_raw_value        86
# 21                                uninsured_raw_value         0
# 22                  primary_care_physicians_raw_value       134
# 23     ratio_of_population_to_primary_care_physicians       134
# 24                                 dentists_raw_value        85
# 25                    ratio_of_population_to_dentists        85
# 26                  mental_health_providers_raw_value       230
# 27     ratio_of_population_to_mental_health_providers       230
# 28               preventable_hospital_stays_raw_value        17
# 29                    mammography_screening_raw_value        11
# 30                         flu_vaccinations_raw_value        10
# 31                   high_school_graduation_raw_value        77
# 32                             some_college_raw_value         0
# 33                             unemployment_raw_value         0
# 34                      children_in_poverty_raw_value         0
# 35                        income_inequality_raw_value         0
# 36     children_in_single_parent_households_raw_value         0
# 37                      social_associations_raw_value         0
# 38                            violent_crime_raw_value       173
# 39                            injury_deaths_raw_value        47
# 40         air_pollution_particulate_matter_raw_value        29
# 41                drinking_water_violations_raw_value        42
# 42                  severe_housing_problems_raw_value         0
# 43   percentage_of_households_with_high_housing_costs         0
# 44         percentage_of_households_with_overcrowding         0
# 45  percentage_of_households_with_lack_of_kitchen_...         0
# 46                    driving_alone_to_work_raw_value         0
# 47               long_commute_driving_alone_raw_value         0
# 48                          life_expectancy_raw_value        20
# 49         premature_age_adjusted_mortality_raw_value         0
# 50                          child_mortality_raw_value      1161
# 51                         infant_mortality_raw_value      1821
# 52               frequent_physical_distress_raw_value         0
# 53                 frequent_mental_distress_raw_value         0
# 54                      diabetes_prevalence_raw_value         0
# 55                           hiv_prevalence_raw_value       660
# 56                          food_insecurity_raw_value         0
# 57          limited_access_to_healthy_foods_raw_value        19
# 58                     drug_overdose_deaths_raw_value      1361
# 59               motor_vehicle_crash_deaths_raw_value       382
# 60                       insufficient_sleep_raw_value         0
# 61                         uninsured_adults_raw_value         0
# 62                       uninsured_children_raw_value         0
# 63             other_primary_care_providers_raw_value        26
# 64  ratio_of_population_to_primary_care_providers_...        26
# 65                       disconnected_youth_raw_value      1669
# 66                  median_household_income_raw_value         0
# 67  children_eligible_for_free_or_reduced_price_lu...       118
# 68                                homicides_raw_value      1809
# 69                       firearm_fatalities_raw_value       872
# 70                            homeownership_raw_value         0
# 71               severe_housing_cost_burden_raw_value         0
# 72                               population_raw_value         0
# 73                pct_below_18_years_of_age_raw_value         0
# 74                         pct_65_and_older_raw_value         0
# 75        pct_non_hispanic_african_american_raw_value         0
# 76   pct_american_indian_and_alaskan_native_raw_value         0
# 77                                pct_asian_raw_value         0
# 78  pct_native_hawaiian_other_pacific_islander_raw...         0
# 79                             pct_hispanic_raw_value         0
# 80                   pct_non_hispanic_white_raw_value         0
# 81            pct_not_proficient_in_english_raw_value         0
# 82                              pct_females_raw_value         0
# 83                                pct_rural_raw_value         0

# %%
# looking at the columns with full coverage
print(county_na_count_df[county_na_count_df.na_count == 0].shape[0])
county_na_count_df[county_na_count_df.na_count == 0]
# Out:
# 51
#                                                column  na_count
# 0                                           statecode         0
# 1                                          countycode         0
# 2                                            fipscode         0
# 3                                               state         0
# 4                                              county         0
# 5                                                year         0
# 6                                       county_ranked         0
# 7                           premature_death_raw_value         0
# 8                       poor_or_fair_health_raw_value         0
# 9                 poor_physical_health_days_raw_value         0
# 10                  poor_mental_health_days_raw_value         0
# 12                            adult_smoking_raw_value         0
# 13                            adult_obesity_raw_value         0
# 15                      physical_inactivity_raw_value         0
# 17                       excessive_drinking_raw_value         0
# 21                                uninsured_raw_value         0
# 32                             some_college_raw_value         0
# 33                             unemployment_raw_value         0
# 34                      children_in_poverty_raw_value         0
# 35                        income_inequality_raw_value         0
# 36     children_in_single_parent_households_raw_value         0
# 37                      social_associations_raw_value         0
# 42                  severe_housing_problems_raw_value         0
# 43   percentage_of_households_with_high_housing_costs         0
# 44         percentage_of_households_with_overcrowding         0
# 45  percentage_of_households_with_lack_of_kitchen_...         0
# 46                    driving_alone_to_work_raw_value         0
# 47               long_commute_driving_alone_raw_value         0
# 49         premature_age_adjusted_mortality_raw_value         0
# 52               frequent_physical_distress_raw_value         0
# 53                 frequent_mental_distress_raw_value         0
# 54                      diabetes_prevalence_raw_value         0
# 56                          food_insecurity_raw_value         0
# 60                       insufficient_sleep_raw_value         0
# 61                         uninsured_adults_raw_value         0
# 62                       uninsured_children_raw_value         0
# 66                  median_household_income_raw_value         0
# 70                            homeownership_raw_value         0
# 71               severe_housing_cost_burden_raw_value         0
# 72                               population_raw_value         0
# 73                pct_below_18_years_of_age_raw_value         0
# 74                         pct_65_and_older_raw_value         0
# 75        pct_non_hispanic_african_american_raw_value         0
# 76   pct_american_indian_and_alaskan_native_raw_value         0
# 77                                pct_asian_raw_value         0
# 78  pct_native_hawaiian_other_pacific_islander_raw...         0
# 79                             pct_hispanic_raw_value         0
# 80                   pct_non_hispanic_white_raw_value         0
# 81            pct_not_proficient_in_english_raw_value         0
# 82                              pct_females_raw_value         0
# 83                                pct_rural_raw_value         0

# %%
# values are all numbers, which is good
county_health_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 84 columns):
# statecode                                                               3081 non-null int64
# countycode                                                              3081 non-null int64
# fipscode                                                                3081 non-null int64
# state                                                                   3081 non-null object
# county                                                                  3081 non-null object
# year                                                                    3081 non-null int64
# county_ranked                                                           3081 non-null float64
# premature_death_raw_value                                               3081 non-null float64
# poor_or_fair_health_raw_value                                           3081 non-null float64
# poor_physical_health_days_raw_value                                     3081 non-null float64
# poor_mental_health_days_raw_value                                       3081 non-null float64
# low_birthweight_raw_value                                               3028 non-null float64
# adult_smoking_raw_value                                                 3081 non-null float64
# adult_obesity_raw_value                                                 3081 non-null float64
# food_environment_index_raw_value                                        3062 non-null float64
# physical_inactivity_raw_value                                           3081 non-null float64
# access_to_exercise_opportunities_raw_value                              3076 non-null float64
# excessive_drinking_raw_value                                            3081 non-null float64
# alcohol_impaired_driving_deaths_raw_value                               3059 non-null float64
# sexually_transmitted_infections_raw_value                               2976 non-null float64
# teen_births_raw_value                                                   2995 non-null float64
# uninsured_raw_value                                                     3081 non-null float64
# primary_care_physicians_raw_value                                       2947 non-null float64
# ratio_of_population_to_primary_care_physicians                          2947 non-null float64
# dentists_raw_value                                                      2996 non-null float64
# ratio_of_population_to_dentists                                         2996 non-null float64
# mental_health_providers_raw_value                                       2851 non-null float64
# ratio_of_population_to_mental_health_providers                          2851 non-null float64
# preventable_hospital_stays_raw_value                                    3064 non-null float64
# mammography_screening_raw_value                                         3070 non-null float64
# flu_vaccinations_raw_value                                              3071 non-null float64
# high_school_graduation_raw_value                                        3004 non-null float64
# some_college_raw_value                                                  3081 non-null float64
# unemployment_raw_value                                                  3081 non-null float64
# children_in_poverty_raw_value                                           3081 non-null float64
# income_inequality_raw_value                                             3081 non-null float64
# children_in_single_parent_households_raw_value                          3081 non-null float64
# social_associations_raw_value                                           3081 non-null float64
# violent_crime_raw_value                                                 2908 non-null float64
# injury_deaths_raw_value                                                 3034 non-null float64
# air_pollution_particulate_matter_raw_value                              3052 non-null float64
# drinking_water_violations_raw_value                                     3039 non-null float64
# severe_housing_problems_raw_value                                       3081 non-null float64
# percentage_of_households_with_high_housing_costs                        3081 non-null float64
# percentage_of_households_with_overcrowding                              3081 non-null float64
# percentage_of_households_with_lack_of_kitchen_or_plumbing_facilities    3081 non-null float64
# driving_alone_to_work_raw_value                                         3081 non-null float64
# long_commute_driving_alone_raw_value                                    3081 non-null float64
# life_expectancy_raw_value                                               3061 non-null float64
# premature_age_adjusted_mortality_raw_value                              3081 non-null float64
# child_mortality_raw_value                                               1920 non-null float64
# infant_mortality_raw_value                                              1260 non-null float64
# frequent_physical_distress_raw_value                                    3081 non-null float64
# frequent_mental_distress_raw_value                                      3081 non-null float64
# diabetes_prevalence_raw_value                                           3081 non-null float64
# hiv_prevalence_raw_value                                                2421 non-null float64
# food_insecurity_raw_value                                               3081 non-null float64
# limited_access_to_healthy_foods_raw_value                               3062 non-null float64
# drug_overdose_deaths_raw_value                                          1720 non-null float64
# motor_vehicle_crash_deaths_raw_value                                    2699 non-null float64
# insufficient_sleep_raw_value                                            3081 non-null float64
# uninsured_adults_raw_value                                              3081 non-null float64
# uninsured_children_raw_value                                            3081 non-null float64
# other_primary_care_providers_raw_value                                  3055 non-null float64
# ratio_of_population_to_primary_care_providers_other_than_physicians     3055 non-null float64
# disconnected_youth_raw_value                                            1412 non-null float64
# median_household_income_raw_value                                       3081 non-null float64
# children_eligible_for_free_or_reduced_price_lunch_raw_value             2963 non-null float64
# homicides_raw_value                                                     1272 non-null float64
# firearm_fatalities_raw_value                                            2209 non-null float64
# homeownership_raw_value                                                 3081 non-null float64
# severe_housing_cost_burden_raw_value                                    3081 non-null float64
# population_raw_value                                                    3081 non-null int64
# pct_below_18_years_of_age_raw_value                                     3081 non-null float64
# pct_65_and_older_raw_value                                              3081 non-null float64
# pct_non_hispanic_african_american_raw_value                             3081 non-null float64
# pct_american_indian_and_alaskan_native_raw_value                        3081 non-null float64
# pct_asian_raw_value                                                     3081 non-null float64
# pct_native_hawaiian_other_pacific_islander_raw_value                    3081 non-null float64
# pct_hispanic_raw_value                                                  3081 non-null float64
# pct_non_hispanic_white_raw_value                                        3081 non-null float64
# pct_not_proficient_in_english_raw_value                                 3081 non-null float64
# pct_females_raw_value                                                   3081 non-null float64
# pct_rural_raw_value                                                     3081 non-null float64
# dtypes: float64(77), int64(5), object(2)
# memory usage: 2.0+ MB

# %%
# Exploring which if any additional columns without NaN's emerge when removing the lowest population counties
for pop in np.linspace(0,20000,21):
    temp = clean.column_na_count_df(county_health_df[county_health_df.population_raw_value > pop])
    print("Population limit: ",pop)
    print("Number of rows: ",county_health_df[county_health_df.population_raw_value > pop].shape[0])
    temp_cols = set(temp.column[temp.na_count == 0])
    orig_cols = set(county_na_count_df.column[county_na_count_df.na_count == 0])
    added_cols = list(temp_cols - orig_cols)
    print("New columns with no NaNs", added_cols)
# Out:
# Population limit:  0.0
# Number of rows:  3081
# New columns with no NaNs []
# Population limit:  1000.0
# Number of rows:  3079
# New columns with no NaNs []
# Population limit:  2000.0
# Number of rows:  3043
# New columns with no NaNs ['life_expectancy_raw_value']
# Population limit:  3000.0
# Number of rows:  2967
# New columns with no NaNs ['life_expectancy_raw_value']
# Population limit:  4000.0
# Number of rows:  2902
# New columns with no NaNs ['life_expectancy_raw_value']
# Population limit:  5000.0
# Number of rows:  2832
# New columns with no NaNs ['life_expectancy_raw_value']
# Population limit:  6000.0
# Number of rows:  2748
# New columns with no NaNs ['low_birthweight_raw_value', 'life_expectancy_raw_value']
# Population limit:  7000.0
# Number of rows:  2671
# New columns with no NaNs ['low_birthweight_raw_value', 'life_expectancy_raw_value']
# Population limit:  8000.0
# Number of rows:  2593
# New columns with no NaNs ['low_birthweight_raw_value', 'life_expectancy_raw_value']
# Population limit:  9000.0
# Number of rows:  2502
# New columns with no NaNs ['low_birthweight_raw_value', 'access_to_exercise_opportunities_raw_value', 'life_expectancy_raw_value']
# Population limit:  10000.0
# Number of rows:  2431
# New columns with no NaNs ['low_birthweight_raw_value', 'access_to_exercise_opportunities_raw_value', 'life_expectancy_raw_value']
# Population limit:  11000.0
# Number of rows:  2353
# New columns with no NaNs ['low_birthweight_raw_value', 'access_to_exercise_opportunities_raw_value', 'life_expectancy_raw_value']
# Population limit:  12000.0
# Number of rows:  2293
# New columns with no NaNs ['low_birthweight_raw_value', 'access_to_exercise_opportunities_raw_value', 'life_expectancy_raw_value']
# Population limit:  13000.0
# Number of rows:  2228
# New columns with no NaNs ['low_birthweight_raw_value', 'access_to_exercise_opportunities_raw_value', 'life_expectancy_raw_value']
# Population limit:  14000.0
# Number of rows:  2162
# New columns with no NaNs ['low_birthweight_raw_value', 'access_to_exercise_opportunities_raw_value', 'life_expectancy_raw_value']
# Population limit:  15000.0
# Number of rows:  2098
# New columns with no NaNs ['low_birthweight_raw_value', 'access_to_exercise_opportunities_raw_value', 'life_expectancy_raw_value']
# Population limit:  16000.0
# Number of rows:  2040
# New columns with no NaNs ['low_birthweight_raw_value', 'access_to_exercise_opportunities_raw_value', 'life_expectancy_raw_value']
# Population limit:  17000.0
# Number of rows:  1978
# New columns with no NaNs ['flu_vaccinations_raw_value', 'teen_births_raw_value', 'low_birthweight_raw_value', 'alcohol_impaired_driving_deaths_raw_value', 'access_to_exercise_opportunities_raw_value', 'life_expectancy_raw_value']
# Population limit:  18000.0
# Number of rows:  1918
# New columns with no NaNs ['flu_vaccinations_raw_value', 'teen_births_raw_value', 'low_birthweight_raw_value', 'alcohol_impaired_driving_deaths_raw_value', 'access_to_exercise_opportunities_raw_value', 'life_expectancy_raw_value']
# Population limit:  19000.0
# Number of rows:  1872
# New columns with no NaNs ['flu_vaccinations_raw_value', 'teen_births_raw_value', 'low_birthweight_raw_value', 'alcohol_impaired_driving_deaths_raw_value', 'access_to_exercise_opportunities_raw_value', 'life_expectancy_raw_value']
# Population limit:  20000.0
# Number of rows:  1827
# New columns with no NaNs ['flu_vaccinations_raw_value', 'teen_births_raw_value', 'low_birthweight_raw_value', 'alcohol_impaired_driving_deaths_raw_value', 'access_to_exercise_opportunities_raw_value', 'life_expectancy_raw_value']

# %%
# removing populations below 6000 to get birthweigt and reduce nulls in other categories
big_county_health_df = county_health_df[county_health_df.population_raw_value > 6000].copy()
big_county_health_df.reset_index(inplace=True, drop=True)

# %%
# Bedford County was the only county missing injury_deaths_raw_value. 
# This seemed important so we independently identified it from the same data source that the 
# dataset used and it was inline with expectations (Bedford = 80.8 and state average = 77.2)
bedford_fill = 80.79616282
bedford_index = big_county_health_df[big_county_health_df.fipscode == 51019].index
big_county_health_df.at[bedford_index, 'injury_deaths_raw_value'] = bedford_fill

# %%
# When reviewing the data after partial cleaning, 
# we identified the following 4 columns that we'd like to keep for further investigation,
# so we'll be dropping rows without these data points.
cols_to_keep = ['ratio_of_population_to_primary_care_providers_other_than_physicians',
                'flu_vaccinations_raw_value',
                'preventable_hospital_stays_raw_value',
                'high_school_graduation_raw_value']
big_county_health_df.dropna(axis=0, subset=cols_to_keep, inplace=True, how='any')

# %%
# exploring where NaN's remain
big_county_na_count_df = clean.column_na_count_df(big_county_health_df)
print(big_county_na_count_df[big_county_na_count_df.na_count > 0].shape[0])
big_county_na_count_df[big_county_na_count_df.na_count > 0]
# Out:
# 24
#                                                column  na_count
# 14                   food_environment_index_raw_value        18
# 16         access_to_exercise_opportunities_raw_value         1
# 18          alcohol_impaired_driving_deaths_raw_value         4
# 19          sexually_transmitted_infections_raw_value         7
# 20                              teen_births_raw_value         2
# 22                  primary_care_physicians_raw_value        55
# 23     ratio_of_population_to_primary_care_physicians        55
# 24                                 dentists_raw_value        41
# 25                    ratio_of_population_to_dentists        41
# 26                  mental_health_providers_raw_value        72
# 27     ratio_of_population_to_mental_health_providers        72
# 38                            violent_crime_raw_value       132
# 40         air_pollution_particulate_matter_raw_value        15
# 41                drinking_water_violations_raw_value        34
# 50                          child_mortality_raw_value       795
# 51                         infant_mortality_raw_value      1445
# 55                           hiv_prevalence_raw_value       340
# 57          limited_access_to_healthy_foods_raw_value        18
# 58                     drug_overdose_deaths_raw_value       987
# 59               motor_vehicle_crash_deaths_raw_value       114
# 65                       disconnected_youth_raw_value      1305
# 67  children_eligible_for_free_or_reduced_price_lu...       114
# 68                                homicides_raw_value      1436
# 69                       firearm_fatalities_raw_value       517

# %%
print(big_county_na_count_df[big_county_na_count_df.na_count == 0].shape[0])
big_county_na_count_df[big_county_na_count_df.na_count == 0]
# Out:
# 60
#                                                column  na_count
# 0                                           statecode         0
# 1                                          countycode         0
# 2                                            fipscode         0
# 3                                               state         0
# 4                                              county         0
# 5                                                year         0
# 6                                       county_ranked         0
# 7                           premature_death_raw_value         0
# 8                       poor_or_fair_health_raw_value         0
# 9                 poor_physical_health_days_raw_value         0
# 10                  poor_mental_health_days_raw_value         0
# 11                          low_birthweight_raw_value         0
# 12                            adult_smoking_raw_value         0
# 13                            adult_obesity_raw_value         0
# 15                      physical_inactivity_raw_value         0
# 17                       excessive_drinking_raw_value         0
# 21                                uninsured_raw_value         0
# 28               preventable_hospital_stays_raw_value         0
# 29                    mammography_screening_raw_value         0
# 30                         flu_vaccinations_raw_value         0
# 31                   high_school_graduation_raw_value         0
# 32                             some_college_raw_value         0
# 33                             unemployment_raw_value         0
# 34                      children_in_poverty_raw_value         0
# 35                        income_inequality_raw_value         0
# 36     children_in_single_parent_households_raw_value         0
# 37                      social_associations_raw_value         0
# 39                            injury_deaths_raw_value         0
# 42                  severe_housing_problems_raw_value         0
# 43   percentage_of_households_with_high_housing_costs         0
# 44         percentage_of_households_with_overcrowding         0
# 45  percentage_of_households_with_lack_of_kitchen_...         0
# 46                    driving_alone_to_work_raw_value         0
# 47               long_commute_driving_alone_raw_value         0
# 48                          life_expectancy_raw_value         0
# 49         premature_age_adjusted_mortality_raw_value         0
# 52               frequent_physical_distress_raw_value         0
# 53                 frequent_mental_distress_raw_value         0
# 54                      diabetes_prevalence_raw_value         0
# 56                          food_insecurity_raw_value         0
# 60                       insufficient_sleep_raw_value         0
# 61                         uninsured_adults_raw_value         0
# 62                       uninsured_children_raw_value         0
# 63             other_primary_care_providers_raw_value         0
# 64  ratio_of_population_to_primary_care_providers_...         0
# 66                  median_household_income_raw_value         0
# 70                            homeownership_raw_value         0
# 71               severe_housing_cost_burden_raw_value         0
# 72                               population_raw_value         0
# 73                pct_below_18_years_of_age_raw_value         0
# 74                         pct_65_and_older_raw_value         0
# 75        pct_non_hispanic_african_american_raw_value         0
# 76   pct_american_indian_and_alaskan_native_raw_value         0
# 77                                pct_asian_raw_value         0
# 78  pct_native_hawaiian_other_pacific_islander_raw...         0
# 79                             pct_hispanic_raw_value         0
# 80                   pct_non_hispanic_white_raw_value         0
# 81            pct_not_proficient_in_english_raw_value         0
# 82                              pct_females_raw_value         0
# 83                                pct_rural_raw_value         0

# %%
# dropping remaining columns with NaN's
cleaned_health_df = big_county_health_df.dropna(axis=1, how='any')

# %%
# final data set to begin regression
print(cleaned_health_df.shape)
cleaned_health_df.info()
# Out:
# (2703, 60)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2703 entries, 0 to 2747
# Data columns (total 60 columns):
# statecode                                                               2703 non-null int64
# countycode                                                              2703 non-null int64
# fipscode                                                                2703 non-null int64
# state                                                                   2703 non-null object
# county                                                                  2703 non-null object
# year                                                                    2703 non-null int64
# county_ranked                                                           2703 non-null float64
# premature_death_raw_value                                               2703 non-null float64
# poor_or_fair_health_raw_value                                           2703 non-null float64
# poor_physical_health_days_raw_value                                     2703 non-null float64
# poor_mental_health_days_raw_value                                       2703 non-null float64
# low_birthweight_raw_value                                               2703 non-null float64
# adult_smoking_raw_value                                                 2703 non-null float64
# adult_obesity_raw_value                                                 2703 non-null float64
# physical_inactivity_raw_value                                           2703 non-null float64
# excessive_drinking_raw_value                                            2703 non-null float64
# uninsured_raw_value                                                     2703 non-null float64
# preventable_hospital_stays_raw_value                                    2703 non-null float64
# mammography_screening_raw_value                                         2703 non-null float64
# flu_vaccinations_raw_value                                              2703 non-null float64
# high_school_graduation_raw_value                                        2703 non-null float64
# some_college_raw_value                                                  2703 non-null float64
# unemployment_raw_value                                                  2703 non-null float64
# children_in_poverty_raw_value                                           2703 non-null float64
# income_inequality_raw_value                                             2703 non-null float64
# children_in_single_parent_households_raw_value                          2703 non-null float64
# social_associations_raw_value                                           2703 non-null float64
# injury_deaths_raw_value                                                 2703 non-null float64
# severe_housing_problems_raw_value                                       2703 non-null float64
# percentage_of_households_with_high_housing_costs                        2703 non-null float64
# percentage_of_households_with_overcrowding                              2703 non-null float64
# percentage_of_households_with_lack_of_kitchen_or_plumbing_facilities    2703 non-null float64
# driving_alone_to_work_raw_value                                         2703 non-null float64
# long_commute_driving_alone_raw_value                                    2703 non-null float64
# life_expectancy_raw_value                                               2703 non-null float64
# premature_age_adjusted_mortality_raw_value                              2703 non-null float64
# frequent_physical_distress_raw_value                                    2703 non-null float64
# frequent_mental_distress_raw_value                                      2703 non-null float64
# diabetes_prevalence_raw_value                                           2703 non-null float64
# food_insecurity_raw_value                                               2703 non-null float64
# insufficient_sleep_raw_value                                            2703 non-null float64
# uninsured_adults_raw_value                                              2703 non-null float64
# uninsured_children_raw_value                                            2703 non-null float64
# other_primary_care_providers_raw_value                                  2703 non-null float64
# ratio_of_population_to_primary_care_providers_other_than_physicians     2703 non-null float64
# median_household_income_raw_value                                       2703 non-null float64
# homeownership_raw_value                                                 2703 non-null float64
# severe_housing_cost_burden_raw_value                                    2703 non-null float64
# population_raw_value                                                    2703 non-null int64
# pct_below_18_years_of_age_raw_value                                     2703 non-null float64
# pct_65_and_older_raw_value                                              2703 non-null float64
# pct_non_hispanic_african_american_raw_value                             2703 non-null float64
# pct_american_indian_and_alaskan_native_raw_value                        2703 non-null float64
# pct_asian_raw_value                                                     2703 non-null float64
# pct_native_hawaiian_other_pacific_islander_raw_value                    2703 non-null float64
# pct_hispanic_raw_value                                                  2703 non-null float64
# pct_non_hispanic_white_raw_value                                        2703 non-null float64
# pct_not_proficient_in_english_raw_value                                 2703 non-null float64
# pct_females_raw_value                                                   2703 non-null float64
# pct_rural_raw_value                                                     2703 non-null float64
# dtypes: float64(53), int64(5), object(2)
# memory usage: 1.3+ MB

# %%
# writing to csv for easy import into other notebooks
cleaned_health_df.to_csv('cleaned_county_health_data.csv', index=False)
