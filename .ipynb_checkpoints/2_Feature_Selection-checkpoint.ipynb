# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
pd.set_option("display.max_columns", 500)
# %matplotlib inline

# %%
cleaned_county_data = pd.read_csv("data/cleaned_county_health_data_1-2.csv")

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
health_behaviors = ['adult_smoking', 'adult_obesity', 'food_environment_index',
                    'physical_inactivity', 'access_to_exercise_opportunities',
                    'excessive_drinking', 'alcohol_impaired_driving_deaths',
                    'sexually_transmitted_infections', 'teen_births']

clinical_care = ['uninsured', 'primary_care_physicians', 'dentists',
                 'mental_health_providers', 'preventable_hospital_stays',
                 'mammography_screening', 'flu_vaccinations']

socio_econ_environ = ['high_school_graduation', 'some_college', 'unemployment',
                      'children_in_poverty', 'income_inequality',
                      'children_in_single_parent_households', 'social_associations',
                      'violent_crime', 'injury_deaths']

phys_environ = ['air_pollution_particulate_matter', 'drinking_water_violations',
                'severe_housing_problems', 'driving_alone_to_work',
                'long_commute_driving_alone']

factor_groups = [health_behaviors, clinical_care,
                 socio_econ_environ, phys_environ]

# %%
target_var = ["premature_death"]
admin_vars = ["statecode", "countycode", "fipscode", "state", "county", "year", "county_ranked"]

# %%
target = cleaned_county_data[target_var]
features = cleaned_county_data.drop(columns = admin_vars+target_var)

X_train, X_test, y_train, y_test = train_test_split(features, target, random_state = 12, test_size = .2)

# %%
train = pd.merge(y_train, X_train, left_index=True, right_index=True)

# %%
pipe = Pipeline([
   ('sc', StandardScaler()),
   ('lr', LinearRegression())])
baseline = cross_val_score(pipe, X_train, y_train, cv=5)

# %%
print(np.mean(baseline))
print(np.std(baseline))
# Out:
# 0.843089809726117
# 0.0050775666525544215

# %%
X_train_sm = StandardScaler().fit_transform(X_train)
y_train_sm = StandardScaler().fit_transform(y_train) 

X_train_sm = sm.add_constant(X_train_sm)
base_model_sm = sm.OLS(y_train_sm, X_train_sm, hasconst=True)
regress_base = base_model_sm.fit()
regress_base.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.848
# Method:                 Least Squares   F-statistic:                     368.2
# Date:                Tue, 22 Oct 2019   Prob (F-statistic):               0.00
# Time:                        10:07:17   Log-Likelihood:                -929.50
# No. Observations:                1978   AIC:                             1921.
# Df Residuals:                    1947   BIC:                             2094.
# Df Model:                          30
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.474e-16      0.009   9.66e-14      1.000      -0.017       0.017
# x1             0.1236      0.015      8.141      0.000       0.094       0.153
# x2             0.0301      0.014      2.083      0.037       0.002       0.058
# x3            -0.0608      0.015     -4.109      0.000      -0.090      -0.032
# x4             0.0744      0.017      4.449      0.000       0.042       0.107
# x5            -0.0116      0.012     -0.962      0.336      -0.035       0.012
# x6            -0.0716      0.013     -5.509      0.000      -0.097      -0.046
# x7             0.0183      0.009      1.993      0.046       0.000       0.036
# x8             0.0708      0.014      4.954      0.000       0.043       0.099
# x9             0.1493      0.018      8.455      0.000       0.115       0.184
# x10            0.0263      0.013      2.003      0.045       0.001       0.052
# x11           -0.0082      0.013     -0.648      0.517      -0.033       0.017
# x12            0.0015      0.013      0.111      0.912      -0.025       0.028
# x13            0.0280      0.011      2.488      0.013       0.006       0.050
# x14            0.0259      0.011      2.339      0.019       0.004       0.048
# x15           -0.0099      0.012     -0.796      0.426      -0.034       0.014
# x16            0.0200      0.012      1.721      0.085      -0.003       0.043
# x17            0.0373      0.011      3.526      0.000       0.017       0.058
# x18            0.0408      0.016      2.507      0.012       0.009       0.073
# x19            0.0455      0.012      3.652      0.000       0.021       0.070
# x20            0.0975      0.023      4.235      0.000       0.052       0.143
# x21            0.0488      0.013      3.783      0.000       0.023       0.074
# x22            0.0693      0.015      4.600      0.000       0.040       0.099
# x23           -0.0220      0.011     -1.926      0.054      -0.044       0.000
# x24            0.0224      0.012      1.925      0.054      -0.000       0.045
# x25            0.4426      0.011     38.800      0.000       0.420       0.465
# x26            0.0493      0.012      4.289      0.000       0.027       0.072
# x27           -0.0140      0.009     -1.526      0.127      -0.032       0.004
# x28           -0.0363      0.014     -2.623      0.009      -0.063      -0.009
# x29            0.0495      0.012      4.257      0.000       0.027       0.072
# x30            0.0666      0.012      5.665      0.000       0.044       0.090
# ==============================================================================
# Omnibus:                      170.155   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              463.979
# Skew:                           0.467   Prob(JB):                    1.77e-101
# Kurtosis:                       5.181   Cond. No.                         8.32
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
ridge_base = base_model_sm.fit_regularized(L1_wt=0)
ridge_base_data = list(zip(['const']+list(X_train.columns), ridge_base.params))
ridge_base_data_df = pd.DataFrame(ridge_base_data, columns=['Feature','Coef'])
ridge_base_data_df
# Out:
#                                  Feature          Coef
# 0                                  const  8.244200e-16
# 1                          adult_smoking  1.236393e-01
# 2                          adult_obesity  3.012411e-02
# 3                 food_environment_index -6.076151e-02
# 4                    physical_inactivity  7.440241e-02
# 5       access_to_exercise_opportunities -1.162050e-02
# 6                     excessive_drinking -7.164147e-02
# 7        alcohol_impaired_driving_deaths  1.832330e-02
# 8        sexually_transmitted_infections  7.078890e-02
# 9                            teen_births  1.492777e-01
# 10                             uninsured  2.632433e-02
# 11               primary_care_physicians -8.203137e-03
# 12                              dentists  1.471754e-03
# 13               mental_health_providers  2.800860e-02
# 14            preventable_hospital_stays  2.593577e-02
# 15                 mammography_screening -9.862189e-03
# 16                      flu_vaccinations  1.998940e-02
# 17                high_school_graduation  3.732636e-02
# 18                          some_college  4.079869e-02
# 19                          unemployment  4.552645e-02
# 20                   children_in_poverty  9.749016e-02
# 21                     income_inequality  4.876104e-02
# 22  children_in_single_parent_households  6.929958e-02
# 23                   social_associations -2.202610e-02
# 24                         violent_crime  2.235665e-02
# 25                         injury_deaths  4.425795e-01
# 26      air_pollution_particulate_matter  4.933960e-02
# 27             drinking_water_violations -1.402360e-02
# 28               severe_housing_problems -3.627690e-02
# 29                 driving_alone_to_work  4.950387e-02
# 30            long_commute_driving_alone  6.660592e-02

# %%
lasso_base = base_model_sm.fit_regularized(L1_wt=1)
lasso_base_data = list(zip(['const']+list(X_train.columns), lasso_base.params))
lasso_base_data_df = pd.DataFrame(lasso_base_data, columns=['Feature','Coef'])
lasso_base_data_df
# lasso_base_data_df.sort_values(by='Coef')
# Out:
#                                  Feature      Coef
# 0                                  const  0.000000
# 1                          adult_smoking  0.123634
# 2                          adult_obesity  0.030115
# 3                 food_environment_index -0.060760
# 4                    physical_inactivity  0.074401
# 5       access_to_exercise_opportunities -0.011621
# 6                     excessive_drinking -0.071646
# 7        alcohol_impaired_driving_deaths  0.018325
# 8        sexually_transmitted_infections  0.070792
# 9                            teen_births  0.149291
# 10                             uninsured  0.026321
# 11               primary_care_physicians -0.008204
# 12                              dentists  0.001466
# 13               mental_health_providers  0.028008
# 14            preventable_hospital_stays  0.025941
# 15                 mammography_screening -0.009860
# 16                      flu_vaccinations  0.019988
# 17                high_school_graduation  0.037327
# 18                          some_college  0.040799
# 19                          unemployment  0.045528
# 20                   children_in_poverty  0.097482
# 21                     income_inequality  0.048761
# 22  children_in_single_parent_households  0.069301
# 23                   social_associations -0.022024
# 24                         violent_crime  0.022355
# 25                         injury_deaths  0.442578
# 26      air_pollution_particulate_matter  0.049342
# 27             drinking_water_violations -0.014024
# 28               severe_housing_problems -0.036276
# 29                 driving_alone_to_work  0.049502
# 30            long_commute_driving_alone  0.066605

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.heatmap(train[target_var+health_behaviors].corr(),
           center = 0, annot = True)
ax.set_ylim(len(target_var+health_behaviors)+0.5, -0.5);

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.heatmap(train[target_var+clinical_care].corr(),
           center = 0, annot = True)
ax.set_ylim(len(target_var+clinical_care)+0.5, -0.5);

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.heatmap(train[target_var+socio_econ_environ].corr(),
           center = 0, annot = True)
ax.set_ylim(len(target_var+socio_econ_environ)+0.5, -0.5);

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.heatmap(train[target_var+phys_environ].corr(),
           center = 0, annot = True)
ax.set_ylim(len(target_var+phys_environ)+0.5, -0.5);

# %%
all_corr_df = train.corr()
all_corr_df.premature_death.abs().sort_values(ascending=False)
# Out:
# premature_death                         1.000000
# children_in_poverty                     0.738289
# teen_births                             0.707047
# injury_deaths                           0.702457
# adult_smoking                           0.695879
# physical_inactivity                     0.647399
# excessive_drinking                      0.620281
# some_college                            0.582470
# food_environment_index                  0.579951
# children_in_single_parent_households    0.553102
# adult_obesity                           0.512692
# unemployment                            0.477808
# preventable_hospital_stays              0.452075
# access_to_exercise_opportunities        0.440789
# mammography_screening                   0.407670
# income_inequality                       0.399789
# flu_vaccinations                        0.332465
# dentists                                0.328641
# uninsured                               0.321818
# sexually_transmitted_infections         0.314778
# violent_crime                           0.299763
# primary_care_physicians                 0.293171
# driving_alone_to_work                   0.272376
# air_pollution_particulate_matter        0.181920
# high_school_graduation                  0.084780
# long_commute_driving_alone              0.078952
# mental_health_providers                 0.074542
# social_associations                     0.046909
# drinking_water_violations               0.029694
# severe_housing_problems                 0.027755
# alcohol_impaired_driving_deaths         0.004077
# Name: premature_death, dtype: float64

# %%
def variance_inflation_factor_printout(feature_list, df):
    feature_df = df[feature_list]
    vif = [variance_inflation_factor(feature_df.values, i) for i in range(feature_df.shape[1])]
    data = list(zip(feature_list, vif))
    data_df = pd.DataFrame(data, columns=['Feature','VIF'])
    return data_df

# %%
variance_inflation_factor_printout(['primary_care_physicians', 'dentists', 'mental_health_providers'], train)
# Out:
#                    Feature       VIF
# 0  primary_care_physicians  6.263248
# 1                 dentists  6.779399
# 2  mental_health_providers  2.793322

# %% [markdown]
# We eliminated the 'dentist' covariates becaues it showed lower statistically sigificance in our base OLS regression and was also moderately correlated with 'mental_health_providers' and 'primary_care_physicans'  covariates which we are including in our model at this point.
#
# We are also eliminating 'social associations' and 'drinking_water_violations' because they had lower statistically sigificants and low correlation with our target feature (premature death).

# %%
# variance_inflation_factor_printout(health_behaviors, train)

# %%
# variance_inflation_factor_printout(clinical_care, train)

# %%
# variance_inflation_factor_printout(socio_econ_environ, train)

# %%
# variance_inflation_factor_printout(phys_environ, train)

# %%
#hyperparamater tuning

# alphas = [1e-5, 1e-3, 1e-2, 1e-1, .2, .5, .9]
alphas = np.linspace(.1, 1, 10)

results_dict = {}

for alpha in alphas:
    lasso_model = Lasso(alpha = alpha, normalize=True, max_iter=2e5)
    lasso_model.fit(X_train, y_train)
    y_prediction = lasso_model.predict(X_train)
    
    rss = lasso_model.score(X_train, y_train)
    results = [rss] + list(lasso_model.intercept_) + list(lasso_model.coef_)
    results_dict.update({alpha: results})
lasso_cols = ["rss", "intercept"] + list(X_train.columns)
lasso_alphas_df = pd.DataFrame.from_dict(results_dict, orient="index", columns=lasso_cols)
lasso_alphas_df
# Out:
#           rss    intercept  adult_smoking  adult_obesity  \
# 0.1  0.850010 -3646.861767    8571.896326    1474.837687
# 0.2  0.849632 -3326.640003    8622.226485    1390.518631
# 0.3  0.849037 -3002.578424    8670.296281    1283.811659
# 0.4  0.848371 -2787.384158    8768.115896    1196.434822
# 0.5  0.847810 -2691.856998    8910.332226    1164.516969
# 0.6  0.847238 -2614.313146    9056.480585    1158.105265
# 0.7  0.846728 -2422.743181    9176.658821    1096.243068
# 0.8  0.846257 -2250.078931    9276.453449    1041.140894
# 0.9  0.845757 -2083.368265    9371.833872     994.747435
# 1.0  0.845253 -1918.576672    9459.737797     937.145766
#
#      food_environment_index  physical_inactivity  \
# 0.1             -149.006373          3430.634981
# 0.2             -151.720170          3478.967461
# 0.3             -153.787848          3510.090604
# 0.4             -153.875408          3550.590707
# 0.5             -152.533058          3576.741778
# 0.6             -150.802171          3586.181194
# 0.7             -149.683659          3584.440466
# 0.8             -147.960530          3589.642776
# 0.9             -146.539122          3604.412132
# 1.0             -145.052072          3626.503946
#
#      access_to_exercise_opportunities  excessive_drinking  \
# 0.1                       -107.694638        -5222.136942
# 0.2                        -81.249990        -5220.063334
# 0.3                        -49.825955        -5245.607690
# 0.4                        -29.886272        -5277.239687
# 0.5                        -17.704593        -5275.849289
# 0.6                         -3.311543        -5252.678887
# 0.7                         -0.000000        -5251.477685
# 0.8                         -0.000000        -5234.577240
# 0.9                         -0.000000        -5216.098687
# 1.0                         -0.000000        -5219.052552
#
#      alcohol_impaired_driving_deaths  sexually_transmitted_infections  \
# 0.1                       322.439058                         0.772662
# 0.2                       280.898783                         0.784267
# 0.3                       238.092089                         0.797160
# 0.4                       195.305738                         0.796679
# 0.5                       158.083016                         0.778374
# 0.6                       124.172535                         0.755762
# 0.7                        87.451727                         0.742209
# 0.8                        48.290358                         0.728393
# 0.9                         8.760026                         0.713882
# 1.0                         0.000000                         0.698813
#
#      teen_births   uninsured  primary_care_physicians  dentists  \
# 0.1    24.231972  994.701678            -29702.160782      -0.0
# 0.2    24.000256  672.726355             -1494.900640      -0.0
# 0.3    23.708243  348.765857                -0.000000      -0.0
# 0.4    23.732020   83.503634                -0.000000      -0.0
# 0.5    23.818541    0.000000                -0.000000      -0.0
# 0.6    23.755110    0.000000                -0.000000      -0.0
# 0.7    23.588624    0.000000                -0.000000      -0.0
# 0.8    23.455004    0.000000                -0.000000      -0.0
# 0.9    23.345003    0.000000                -0.000000      -0.0
# 1.0    23.260302    0.000000                -0.000000      -0.0
#
#      mental_health_providers  preventable_hospital_stays  \
# 0.1             37812.782461                    0.036721
# 0.2             30923.553720                    0.037063
# 0.3             25098.682159                    0.037652
# 0.4             18656.713776                    0.037888
# 0.5             12323.275572                    0.038017
# 0.6              6651.209488                    0.038089
# 0.7              1369.865811                    0.037765
# 0.8                 0.000000                    0.037277
# 0.9                 0.000000                    0.036755
# 1.0                 0.000000                    0.036397
#
#      mammography_screening  flu_vaccinations  high_school_graduation  \
# 0.1            -262.459072        413.668629             1149.695554
# 0.2            -194.410743        283.070501             1050.914517
# 0.3            -111.940960        156.844032              957.261029
# 0.4             -33.940615         32.000187              856.999000
# 0.5              -0.000000          0.000000              749.289301
# 0.6              -0.000000          0.000000              642.454045
# 0.7              -0.000000          0.000000              523.008214
# 0.8              -0.000000          0.000000              412.810697
# 0.9              -0.000000          0.000000              306.205664
# 1.0              -0.000000          0.000000              199.286547
#
#      some_college  unemployment  children_in_poverty  income_inequality  \
# 0.1    606.047523   6620.809023          2541.159345         160.759589
# 0.2    348.116847   6122.368436          2411.116643         158.808924
# 0.3    105.195741   5583.299145          2283.518494         158.467800
# 0.4      0.000000   5123.895922          2209.887223         155.677673
# 0.5      0.000000   4886.219622          2192.902905         150.541169
# 0.6      0.000000   4734.116677          2180.096927         145.642908
# 0.7      0.000000   4652.901783          2184.330732         143.652590
# 0.8      0.000000   4571.726101          2214.401540         141.016786
# 0.9     -0.000000   4484.512911          2244.665656         137.921028
# 1.0     -0.000000   4365.741550          2273.495021         134.925090
#
#      children_in_single_parent_households  social_associations  violent_crime  \
# 0.1                           1729.362726            -7.998113       0.248619
# 0.2                           1690.696190            -6.768918       0.224785
# 0.3                           1655.902497            -5.579279       0.202708
# 0.4                           1632.395615            -4.496725       0.181049
# 0.5                           1616.770663            -3.399576       0.161919
# 0.6                           1603.300341            -2.316103       0.144006
# 0.7                           1595.052121            -1.772233       0.130075
# 0.8                           1584.150767            -1.208618       0.115527
# 0.9                           1571.369932            -0.613303       0.100346
# 1.0                           1558.939268            -0.008543       0.084933
#
#      injury_deaths  air_pollution_particulate_matter  \
# 0.1      47.049736                         61.751659
# 0.2      46.844009                         60.474615
# 0.3      46.678707                         59.481278
# 0.4      46.517660                         58.513473
# 0.5      46.396833                         57.486728
# 0.6      46.289168                         56.567413
# 0.7      46.135112                         56.061272
# 0.8      45.942899                         55.600172
# 0.9      45.735822                         55.098628
# 1.0      45.512071                         54.837103
#
#      drinking_water_violations  severe_housing_problems  \
# 0.1                 -52.433041             -1770.770214
# 0.2                 -37.656754             -1421.774924
# 0.3                 -23.160754             -1077.156752
# 0.4                  -8.946057              -713.995560
# 0.5                  -0.000000              -369.983354
# 0.6                  -0.000000               -44.667481
# 0.7                  -0.000000                -0.000000
# 0.8                  -0.000000                -0.000000
# 0.9                  -0.000000                -0.000000
# 1.0                  -0.000000                -0.000000
#
#      driving_alone_to_work  long_commute_driving_alone
# 0.1            2023.851260                 1266.408485
# 0.2            2072.265640                 1231.675907
# 0.3            2108.849457                 1181.816971
# 0.4            2135.852673                 1141.540809
# 0.5            2138.194034                 1107.082502
# 0.6            2138.938842                 1070.140003
# 0.7            2096.996529                 1031.106963
# 0.8            2060.060603                 1002.686022
# 0.9            2024.424395                  978.441085
# 1.0            1987.727329                  952.189892

# %%
elims = lasso_alphas_df.iloc[9][lasso_alphas_df.iloc[9]==0].index
elims
# Out:
# Index(['access_to_exercise_opportunities', 'alcohol_impaired_driving_deaths',
#        'uninsured', 'primary_care_physicians', 'dentists',
#        'mental_health_providers', 'mammography_screening', 'flu_vaccinations',
#        'some_college', 'drinking_water_violations', 'severe_housing_problems'],
#       dtype='object')

# %%
refined_X_train = X_train.drop(columns= elims)
len(refined_X_train.columns)
# Out:
# 19
